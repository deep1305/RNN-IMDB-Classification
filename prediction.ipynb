# %%
# Step 1: Import Libraries and Load the Model
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.models import load_model
# Out:
# WARNING:tensorflow:From c:\Users\smart\Videos\Langgraph_course_Udemy\venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Load the IMDB dataset word index
word_index = imdb.get_word_index()
reverse_word_index = {value: key for key, value in word_index.items()}

# %%
# Load the pre-trained model with ReLU activation
model = load_model('simple_rnn_imdb.h5')
model.summary()
# Out:
# WARNING:tensorflow:From c:\Users\smart\Videos\Langgraph_course_Udemy\venv\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding (Embedding)       (None, 500, 128)          1280000
#
#  simple_rnn (SimpleRNN)      (None, 128)               32896
#
#  dense (Dense)               (None, 1)                 129
#
# ...
# Total params: 1313025 (5.01 MB)
# Trainable params: 1313025 (5.01 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.get_weights()
# Out:
# [array([[-0.02938083,  0.04070956,  0.00903455, ..., -0.01245642,
#           0.0363302 , -0.01507533],
#         [ 0.03554486,  0.04016582, -0.00827692, ..., -0.00126096,
#          -0.03717994,  0.02338395],
#         [-0.04935761,  0.00151895, -0.00910979, ..., -0.04404658,
#           0.0909663 ,  0.04657021],
#         ...,
#         [-0.08157085, -0.12398439,  0.05164748, ..., -0.06658401,
#           0.05635057,  0.08428364],
#         [-0.03117579, -0.03674821,  0.11933993, ..., -0.01003601,
#          -0.01133762,  0.03177333],
#         [-0.0882737 , -0.06607135,  0.04664977, ..., -0.0123501 ,
#          -0.03601342, -0.01914508]], dtype=float32),
#  array([[-0.13318376,  0.01187082, -0.07270855, ...,  0.04653293,
#           0.11508745,  0.17263325],
#         [ 0.01213036,  0.12957045,  0.0014344 , ...,  0.08498874,
#          -0.08482303, -0.02872783],
#         [ 0.1307857 , -0.07816728,  0.10768807, ...,  0.06583512,
#          -0.05599955,  0.1356572 ],
# ...

# %%
# Step 2: Helper Functions
# Function to decode reviews
def decode_review(encoded_review):
    return ' '.join([reverse_word_index.get(i - 3, '?') for i in encoded_review])

# Function to preprocess user input
def preprocess_text(text):
    words = text.lower().split()
    encoded_review = [word_index.get(word, 2) + 3 for word in words]
    padded_review = sequence.pad_sequences([encoded_review], maxlen=500)
    return padded_review

# %%
### Prediction  function

def predict_sentiment(review):
    preprocessed_input=preprocess_text(review)

    prediction=model.predict(preprocessed_input)

    sentiment = 'Positive' if prediction[0][0] > 0.5 else 'Negative'
    
    return sentiment, prediction[0][0]

# %%
# Step 4: User Input and Prediction
# Example review for prediction
example_review = "This movie was fantastic! The acting was great and the plot was thrilling."

sentiment,score=predict_sentiment(example_review)

print(f'Review: {example_review}')
print(f'Sentiment: {sentiment}')
print(f'Prediction Score: {score}')
# Out:
# 1/1 [==============================] - 0s 260ms/step
# Review: This movie was fantastic! The acting was great and the plot was thrilling.
# Sentiment: Negative
# Prediction Score: 0.28822749853134155

# %%
# Load the pre-trained model with ReLU activation
model_ten = load_model('simple_rnn_imdb_ten.h5')
model_ten.summary()
# Out:
# WARNING:tensorflow:From c:\Users\smart\Videos\Langgraph_course_Udemy\venv\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding (Embedding)       (None, 500, 128)          1280000
#
#  simple_rnn (SimpleRNN)      (None, 128)               32896
#
#  dense (Dense)               (None, 1)                 129
#
# ...
# Total params: 1313025 (5.01 MB)
# Trainable params: 1313025 (5.01 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
### Prediction  function

def predict_sentiment_ten(review):
    preprocessed_input=preprocess_text(review)

    prediction=model_ten.predict(preprocessed_input)

    sentiment = 'Positive' if prediction[0][0] > 0.5 else 'Negative'
    
    return sentiment, prediction[0][0]

# %%
# Step 4: User Input and Prediction
# Example review for prediction
example_review = "This movie was fantastic! The acting was great and the plot was thrilling."

sentiment,score=predict_sentiment_ten(example_review)

print(f'Review: {example_review}')
print(f'Sentiment: {sentiment}')
print(f'Prediction Score: {score}')
# Out:
# 1/1 [==============================] - 0s 162ms/step
# Review: This movie was fantastic! The acting was great and the plot was thrilling.
# Sentiment: Negative
# Prediction Score: 0.47401806712150574

# %%
# Step 4: User Input and Prediction
# Example review for prediction
example_review = "This movie was worst! The acting was mediocre and the plot was flat."

sentiment,score=predict_sentiment_ten(example_review)

print(f'Review: {example_review}')
print(f'Sentiment: {sentiment}')
print(f'Prediction Score: {score}')
# Out:
# 1/1 [==============================] - 0s 67ms/step
# Review: This movie was worst! The acting was mediocre and the plot was flat.
# Sentiment: Negative
# Prediction Score: 0.07228117436170578

# %%
# Step 4: User Input and Prediction
# Example review for prediction
example_review = "This movie was worst! The acting was mediocre and the plot was flat."

sentiment,score=predict_sentiment(example_review)

print(f'Review: {example_review}')
print(f'Sentiment: {sentiment}')
print(f'Prediction Score: {score}')
# Out:
# 1/1 [==============================] - 0s 79ms/step
# Review: This movie was worst! The acting was mediocre and the plot was flat.
# Sentiment: Negative
# Prediction Score: 0.08669909834861755

# %%
# Step 4: User Input and Prediction
# Example review for prediction
example_review = "This movie was great! The acting was superb and the plot was thrilling."

sentiment,score=predict_sentiment_ten(example_review)

print(f'Review: {example_review}')
print(f'Sentiment: {sentiment}')
print(f'Prediction Score: {score}')
# Out:
# 1/1 [==============================] - 0s 100ms/step
# Review: This movie was great! The acting was superb and the plot was thrilling.
# Sentiment: Negative
# Prediction Score: 0.11781875789165497

# %%
# Load the pre-trained model with ReLU activation
model_batch64 = load_model('simple_rnn_imdb_batch_64.h5')
model_batch64.summary()
# Out:
# WARNING:tensorflow:From c:\Users\smart\Videos\Langgraph_course_Udemy\venv\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding (Embedding)       (None, 500, 128)          1280000
#
#  simple_rnn (SimpleRNN)      (None, 128)               32896
#
#  dense (Dense)               (None, 1)                 129
#
# ...
# Total params: 1313025 (5.01 MB)
# Trainable params: 1313025 (5.01 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
### Prediction  function

def predict_sentiment_batch64(review):
    preprocessed_input=preprocess_text(review)

    prediction=model_batch64.predict(preprocessed_input)

    sentiment = 'Positive' if prediction[0][0] > 0.5 else 'Negative'
    
    return sentiment, prediction[0][0]

# %%
# Step 4: User Input and Prediction
# Example review for prediction
example_review = "This movie was worst! The acting was mediocre and the plot was flat."

sentiment,score=predict_sentiment_batch64(example_review)

print(f'Review: {example_review}')
print(f'Sentiment: {sentiment}')
print(f'Prediction Score: {score}')
# Out:
# 1/1 [==============================] - 0s 154ms/step
# Review: This movie was worst! The acting was mediocre and the plot was flat.
# Sentiment: Negative
# Prediction Score: 0.4770796597003937

# %%
example_review = "This movie was great! The acting was great and the plot was great."


sentiment,score=predict_sentiment_batch64(example_review)

print(f'Review: {example_review}')
print(f'Sentiment: {sentiment}')
print(f'Prediction Score: {score}')
# Out:
# 1/1 [==============================] - 0s 46ms/step
# Review: This movie was great! The acting was great and the plot was great.
# Sentiment: Positive
# Prediction Score: 0.6259841322898865
